# %%
import cv2
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8s.pt")

# Define simple colors for classes
def get_colour(cls_num):
    colours = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]
    return colours[cls_num % len(colours)]
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 1.4MB/s 15.7s5.7s<0.1s0ss5
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 1.4MB/s 15.7s

# %%
import time

# --- Camera Initialization ---
cap = cv2.VideoCapture(0)  # 0 = default webcam
if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam opened successfully. Starting detection for 15 seconds...")
    # Give webcam time to initialize
    time.sleep(2) 

    # --- Main Detection Loop (No GUI) ---
    start_time = time.time()
    while time.time() - start_time < 15: # Run for 15 seconds
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        # Run YOLO detection on the frame
        results = model(frame, verbose=False) # verbose=False to reduce console spam

        # Process and print results
        for r in results:
            if len(r.boxes) > 0:
                print(f"--- Frame captured at {time.time() - start_time:.2f}s ---")
                for box in r.boxes:
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    cls = int(box.cls[0])
                    conf = float(box.conf[0])
                    if conf > 0.4:  # filter low confidence
                        print(f"  - Detected '{r.names[cls]}' with confidence {conf:.2f}")
        
        # Small delay
        time.sleep(0.1)

    # --- Cleanup ---
    print("\nDetection finished. Releasing webcam.")
    cap.release()
    # No cv2.destroyAllWindows() needed as no windows were created
    print("Webcam released.")
# Out:
# Webcam opened successfully. Starting detection for 15 seconds...
# --- Frame captured at 0.39s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.89
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.83
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.53
#   - Detected 'chair' with confidence 0.50
# --- Frame captured at 0.39s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.89
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.83
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.53
#   - Detected 'chair' with confidence 0.50
# --- Frame captured at 0.77s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.86
#   - Detected 'chair' with confidence 0.81
#   - Detected 'person' with confidence 0.69
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'chair' with confidence 0.60
#   - Detected 'chair' with confidence 0.51
# --- Frame captured at 0.77s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.86
#   - Detected 'chair' with confidence 0.81
#   - Detected 'person' with confidence 0.69
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'chair' with confidence 0.60
#   - Detected 'chair' with confidence 0.51
# --- Frame captured at 1.13s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.79
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.65
#   - Detected 'chair' with confidence 0.58
#   - Detected 'laptop' with confidence 0.57
# --- Frame captured at 1.13s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.79
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.65
#   - Detected 'chair' with confidence 0.58
#   - Detected 'laptop' with confidence 0.57
# --- Frame captured at 1.48s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'laptop' with confidence 0.66
#   - Detected 'person' with confidence 0.65
#   - Detected 'chair' with confidence 0.57
#   - Detected 'chair' with confidence 0.47
# --- Frame captured at 1.48s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'laptop' with confidence 0.66
#   - Detected 'person' with confidence 0.65
#   - Detected 'chair' with confidence 0.57
#   - Detected 'chair' with confidence 0.47
# --- Frame captured at 1.85s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.76
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.53
#   - Detected 'person' with confidence 0.48
#   - Detected 'chair' with confidence 0.43
#   - Detected 'person' with confidence 0.43
# --- Frame captured at 1.85s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.76
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.53
#   - Detected 'person' with confidence 0.48
#   - Detected 'chair' with confidence 0.43
#   - Detected 'person' with confidence 0.43
# --- Frame captured at 2.23s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.84
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'chair' with confidence 0.54
#   - Detected 'person' with confidence 0.54
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 2.23s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.84
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'chair' with confidence 0.54
#   - Detected 'person' with confidence 0.54
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 2.60s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'chair' with confidence 0.56
#   - Detected 'person' with confidence 0.53
# --- Frame captured at 2.60s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'chair' with confidence 0.56
#   - Detected 'person' with confidence 0.53
# --- Frame captured at 2.96s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'chair' with confidence 0.53
#   - Detected 'chair' with confidence 0.46
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 2.96s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'chair' with confidence 0.53
#   - Detected 'chair' with confidence 0.46
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 3.26s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'chair' with confidence 0.52
#   - Detected 'chair' with confidence 0.50
#   - Detected 'laptop' with confidence 0.47
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 3.26s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'chair' with confidence 0.52
#   - Detected 'chair' with confidence 0.50
#   - Detected 'laptop' with confidence 0.47
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 3.63s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.55
#   - Detected 'chair' with confidence 0.49
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 3.63s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.55
#   - Detected 'chair' with confidence 0.49
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 3.99s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.68
#   - Detected 'person' with confidence 0.58
#   - Detected 'chair' with confidence 0.48
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 3.99s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.68
#   - Detected 'person' with confidence 0.58
#   - Detected 'chair' with confidence 0.48
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 4.30s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'person' with confidence 0.59
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 4.30s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'person' with confidence 0.59
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 4.62s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.83
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'person' with confidence 0.59
#   - Detected 'chair' with confidence 0.42
# --- Frame captured at 4.62s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.83
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'person' with confidence 0.59
#   - Detected 'chair' with confidence 0.42
# --- Frame captured at 4.98s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.84
#   - Detected 'chair' with confidence 0.80
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'chair' with confidence 0.46
# --- Frame captured at 4.98s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.84
#   - Detected 'chair' with confidence 0.80
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'chair' with confidence 0.46
# --- Frame captured at 5.35s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.77
#   - Detected 'person' with confidence 0.61
#   - Detected 'laptop' with confidence 0.58
#   - Detected 'chair' with confidence 0.43
#   - Detected 'chair' with confidence 0.42
# --- Frame captured at 5.35s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.77
#   - Detected 'person' with confidence 0.61
#   - Detected 'laptop' with confidence 0.58
#   - Detected 'chair' with confidence 0.43
#   - Detected 'chair' with confidence 0.42
# --- Frame captured at 5.71s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'person' with confidence 0.62
#   - Detected 'chair' with confidence 0.40
# --- Frame captured at 5.71s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.80
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'person' with confidence 0.62
#   - Detected 'chair' with confidence 0.40
# --- Frame captured at 6.04s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'person' with confidence 0.63
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.49
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 6.04s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'person' with confidence 0.63
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.49
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 6.42s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.62
#   - Detected 'person' with confidence 0.58
#   - Detected 'chair' with confidence 0.51
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 6.42s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.79
#   - Detected 'laptop' with confidence 0.62
#   - Detected 'person' with confidence 0.58
#   - Detected 'chair' with confidence 0.51
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 6.81s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.79
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'chair' with confidence 0.50
# --- Frame captured at 6.81s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.79
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'chair' with confidence 0.50
# --- Frame captured at 7.17s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'person' with confidence 0.64
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.45
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 7.17s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'person' with confidence 0.64
#   - Detected 'chair' with confidence 0.61
#   - Detected 'laptop' with confidence 0.45
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 7.56s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.66
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'person' with confidence 0.48
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 7.56s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'person' with confidence 0.68
#   - Detected 'chair' with confidence 0.66
#   - Detected 'laptop' with confidence 0.64
#   - Detected 'person' with confidence 0.48
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 7.87s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'chair' with confidence 0.68
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.50
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 7.87s ---
#   - Detected 'person' with confidence 0.95
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.82
#   - Detected 'laptop' with confidence 0.79
#   - Detected 'chair' with confidence 0.68
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.50
#   - Detected 'chair' with confidence 0.48
# --- Frame captured at 8.22s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.76
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.51
#   - Detected 'person' with confidence 0.51
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 8.22s ---
#   - Detected 'person' with confidence 0.94
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.76
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.51
#   - Detected 'person' with confidence 0.51
#   - Detected 'chair' with confidence 0.41
# --- Frame captured at 8.59s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.66
#   - Detected 'person' with confidence 0.49
#   - Detected 'chair' with confidence 0.45
# --- Frame captured at 8.59s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.66
#   - Detected 'person' with confidence 0.49
#   - Detected 'chair' with confidence 0.45
# --- Frame captured at 8.95s ---
#   - Detected 'person' with confidence 0.91
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.67
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'person' with confidence 0.45
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 8.95s ---
#   - Detected 'person' with confidence 0.91
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.67
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'person' with confidence 0.45
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 9.32s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.59
#   - Detected 'person' with confidence 0.44
#   - Detected 'chair' with confidence 0.40
# --- Frame captured at 9.32s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.81
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.59
#   - Detected 'person' with confidence 0.44
#   - Detected 'chair' with confidence 0.40
# --- Frame captured at 9.70s ---
#   - Detected 'person' with confidence 0.92
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.70
#   - Detected 'person' with confidence 0.68
#   - Detected 'person' with confidence 0.53
#   - Detected 'laptop' with confidence 0.49
# --- Frame captured at 9.70s ---
#   - Detected 'person' with confidence 0.92
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.70
#   - Detected 'person' with confidence 0.68
#   - Detected 'person' with confidence 0.53
#   - Detected 'laptop' with confidence 0.49
# --- Frame captured at 10.08s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.51
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 10.08s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.65
#   - Detected 'person' with confidence 0.51
#   - Detected 'chair' with confidence 0.43
# --- Frame captured at 10.45s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.50
#   - Detected 'person' with confidence 0.49
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 10.45s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.66
#   - Detected 'laptop' with confidence 0.50
#   - Detected 'person' with confidence 0.49
#   - Detected 'person' with confidence 0.45
# --- Frame captured at 10.80s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.63
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'person' with confidence 0.47
#   - Detected 'person' with confidence 0.40
# --- Frame captured at 10.80s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.78
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.63
#   - Detected 'laptop' with confidence 0.61
#   - Detected 'person' with confidence 0.47
#   - Detected 'person' with confidence 0.40
# --- Frame captured at 11.17s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.68
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'person' with confidence 0.43
# --- Frame captured at 11.17s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.87
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.68
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'person' with confidence 0.43
# --- Frame captured at 11.56s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.70
#   - Detected 'laptop' with confidence 0.60
# --- Frame captured at 11.56s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.70
#   - Detected 'laptop' with confidence 0.60
# --- Frame captured at 11.94s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'chair' with confidence 0.46
# --- Frame captured at 11.94s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.67
#   - Detected 'laptop' with confidence 0.63
#   - Detected 'chair' with confidence 0.46
# --- Frame captured at 12.29s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'chair' with confidence 0.42
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 12.29s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.80
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'chair' with confidence 0.42
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 12.66s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.62
#   - Detected 'laptop' with confidence 0.60
#   - Detected 'person' with confidence 0.44
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 12.66s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.81
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.62
#   - Detected 'laptop' with confidence 0.60
#   - Detected 'person' with confidence 0.44
#   - Detected 'chair' with confidence 0.44
# --- Frame captured at 13.02s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.54
#   - Detected 'person' with confidence 0.46
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 13.02s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.78
#   - Detected 'person' with confidence 0.65
#   - Detected 'laptop' with confidence 0.54
#   - Detected 'person' with confidence 0.46
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 13.39s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.76
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'person' with confidence 0.49
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 13.39s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.76
#   - Detected 'person' with confidence 0.64
#   - Detected 'laptop' with confidence 0.56
#   - Detected 'person' with confidence 0.49
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 13.78s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.63
#   - Detected 'laptop' with confidence 0.54
#   - Detected 'person' with confidence 0.47
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 13.78s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.77
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.63
#   - Detected 'laptop' with confidence 0.54
#   - Detected 'person' with confidence 0.47
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 14.14s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.66
#   - Detected 'person' with confidence 0.42
#   - Detected 'person' with confidence 0.40
# --- Frame captured at 14.14s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.87
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'chair' with confidence 0.74
#   - Detected 'person' with confidence 0.66
#   - Detected 'person' with confidence 0.42
#   - Detected 'person' with confidence 0.40
# --- Frame captured at 14.51s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.75
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'person' with confidence 0.59
#   - Detected 'laptop' with confidence 0.42
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 14.51s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'chair' with confidence 0.75
#   - Detected 'laptop' with confidence 0.75
#   - Detected 'person' with confidence 0.59
#   - Detected 'laptop' with confidence 0.42
#   - Detected 'person' with confidence 0.41
# --- Frame captured at 14.89s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.76
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.59
#   - Detected 'laptop' with confidence 0.55
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 14.89s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.76
#   - Detected 'chair' with confidence 0.75
#   - Detected 'person' with confidence 0.59
#   - Detected 'laptop' with confidence 0.55
#   - Detected 'person' with confidence 0.44
# --- Frame captured at 15.16s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.62
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'chair' with confidence 0.57
#
# Detection finished. Releasing webcam.
# --- Frame captured at 15.16s ---
#   - Detected 'person' with confidence 0.93
#   - Detected 'chair' with confidence 0.88
#   - Detected 'chair' with confidence 0.86
#   - Detected 'laptop' with confidence 0.82
#   - Detected 'chair' with confidence 0.73
#   - Detected 'person' with confidence 0.62
#   - Detected 'laptop' with confidence 0.57
#   - Detected 'chair' with confidence 0.57
#
# Detection finished. Releasing webcam.
# Webcam released.
# Webcam released.

# %%
cap.release()
# Safely close all OpenCV windows (handles headless environments)
try:
    cv2.destroyAllWindows()
except Exception as e:
    print(f"cv2.destroyAllWindows() failed: {e}")
# Out:
# cv2.destroyAllWindows() failed: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
